# %% [markdown]
# <a href="https://colab.research.google.com/github/Mahsabeigi33/Mobile_price_prediction/blob/main/prediction_mobile.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Mobile price prediction

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('train.csv')

# %%
data
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
data.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# ...

# %%
data.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
x=data.drop('price_range',axis=1)
y=data['price_range']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=4)

# %%
max_depth=150

# %%
Acc=np.zeros((max_depth))
for i in range(1,max_depth+1):
    clf=DecisionTreeClassifier(criterion="entropy",max_depth=i)
    clf.fit(x_train,y_train)
    y_pred=clf.predict(x_test)
    Acc[i-1]=metrics.accuracy_score(y_test,y_pred)
Acc
# Out:
# array([0.516, 0.77 , 0.77 , 0.786, 0.844, 0.85 , 0.858, 0.862, 0.862,
#        0.856, 0.856, 0.85 , 0.858, 0.862, 0.862, 0.858, 0.852, 0.852,
#        0.856, 0.852, 0.856, 0.85 , 0.858, 0.862, 0.862, 0.858, 0.858,
#        0.86 , 0.854, 0.856, 0.852, 0.856, 0.856, 0.848, 0.852, 0.854,
#        0.85 , 0.866, 0.852, 0.852, 0.864, 0.856, 0.85 , 0.86 , 0.858,
#        0.852, 0.86 , 0.866, 0.854, 0.858, 0.858, 0.85 , 0.854, 0.858,
#        0.854, 0.86 , 0.864, 0.846, 0.852, 0.854, 0.864, 0.852, 0.854,
#        0.852, 0.86 , 0.852, 0.854, 0.854, 0.852, 0.864, 0.856, 0.866,
#        0.852, 0.852, 0.854, 0.86 , 0.854, 0.86 , 0.866, 0.856, 0.854,
#        0.846, 0.852, 0.856, 0.864, 0.85 , 0.854, 0.866, 0.858, 0.856,
#        0.852, 0.86 , 0.848, 0.858, 0.864, 0.856, 0.852, 0.854, 0.854,
#        0.86 ])

# %%
clf=DecisionTreeClassifier(criterion="entropy",max_depth=3)
clf.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3)

# %%
y_pred=clf.predict(x_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[101,  28,   0,   0],
#        [ 12,  94,  23,   0],
#        [  0,  21,  75,  17],
#        [  0,   0,  14, 115]], dtype=int64)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.78      0.83       129
#            1       0.66      0.73      0.69       129
#            2       0.67      0.66      0.67       113
#            3       0.87      0.89      0.88       129
#
#     accuracy                           0.77       500
#    macro avg       0.77      0.77      0.77       500
# weighted avg       0.78      0.77      0.77       500

# %%
print("accuracy:",metrics.accuracy_score(y_test,y_pred))
# Out:
# accuracy: 0.77

# %% [markdown]
# # Price prediction  Using DTC ¶
#
# 1.   List item
# 2.   List item

# %%
data_test=pd.read_csv("test.csv")
data_test
# Out:
#        id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0       1           1043     1          1.8         1  14       0           5
# 1       2            841     1          0.5         1   4       1          61
# 2       3           1807     1          2.8         0   1       0          27
# 3       4           1546     0          0.5         1  18       1          25
# 4       5           1434     0          1.4         0  11       1          49
# ..    ...            ...   ...          ...       ...  ..     ...         ...
# 995   996           1700     1          1.9         0   0       1          54
# 996   997            609     0          1.8         1   0       0          13
# 997   998           1185     0          1.4         0   1       1           8
# 998   999           1533     1          0.5         1   0       0          50
# 999  1000           1270     1          0.5         0   4       1          35
#
# ...

# %%
data_test.head()
# Out:
#    id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0   1           1043     1          1.8         1  14       0           5
# 1   2            841     1          0.5         1   4       1          61
# 2   3           1807     1          2.8         0   1       0          27
# 3   4           1546     0          0.5         1  18       1          25
# 4   5           1434     0          1.4         0  11       1          49
#
#    m_dep  mobile_wt  ...  pc  px_height  px_width   ram  sc_h  sc_w  \
# 0    0.1        193  ...  16        226      1412  3476    12     7
# 1    0.8        191  ...  12        746       857  3895     6     0
# 2    0.9        186  ...   4       1270      1366  2396    17    10
# 3    0.5         96  ...  20        295      1752  3893    10     0
# 4    0.5        108  ...  18        749       810  1773    15     8
#
#    talk_time  three_g  touch_screen  wifi
# 0          2        0             1     0
# ...

# %%
data_test=data_test.drop('id',axis=1)

# %%
data_test.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0           1043     1          1.8         1  14       0           5    0.1
# 1            841     1          0.5         1   4       1          61    0.8
# 2           1807     1          2.8         0   1       0          27    0.9
# 3           1546     0          0.5         1  18       1          25    0.5
# 4           1434     0          1.4         0  11       1          49    0.5
#
#    mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        193        3  16        226      1412  3476    12     7          2
# 1        191        5  12        746       857  3895     6     0          7
# 2        186        3   4       1270      1366  2396    17    10         10
# 3         96        8  20        295      1752  3893    10     0          7
# 4        108        6  18        749       810  1773    15     8          7
#
#    three_g  touch_screen  wifi
# ...

# %%
predicted_price=clf.predict(data_test)

# %%
predicted_price
# Out:
# array([3, 3, 2, 3, 1, 3, 3, 1, 3, 0, 3, 3, 0, 0, 2, 0, 1, 1, 3, 2, 1, 3,
#        1, 2, 3, 0, 2, 0, 3, 0, 2, 0, 3, 0, 0, 1, 3, 1, 3, 2, 0, 2, 0, 0,
#        0, 1, 1, 2, 1, 2, 2, 0, 2, 1, 3, 1, 3, 1, 1, 3, 3, 3, 1, 1, 1, 1,
#        1, 2, 1, 1, 1, 1, 2, 3, 3, 0, 2, 0, 2, 3, 1, 3, 3, 0, 3, 0, 3, 1,
#        3, 0, 1, 1, 2, 0, 2, 1, 0, 2, 1, 3, 1, 0, 0, 2, 1, 2, 0, 1, 2, 3,
#        3, 3, 1, 3, 3, 3, 3, 1, 3, 0, 0, 3, 2, 1, 1, 0, 3, 2, 3, 1, 0, 1,
#        1, 2, 3, 1, 1, 0, 3, 2, 1, 3, 2, 2, 3, 3, 3, 2, 2, 3, 3, 3, 0, 1,
#        2, 2, 3, 3, 3, 3, 2, 2, 3, 3, 2, 3, 1, 0, 3, 0, 0, 0, 1, 0, 0, 1,
#        1, 0, 1, 2, 0, 0, 1, 0, 2, 2, 2, 1, 0, 0, 0, 0, 0, 3, 1, 1, 2, 1,
#        2, 3, 1, 2, 3, 3, 3, 1, 2, 0, 0, 1, 1, 2, 1, 2, 3, 3, 0, 2, 0, 3,
#        2, 2, 2, 0, 0, 1, 0, 3, 0, 1, 0, 2, 1, 1, 3, 0, 3, 0, 3, 1, 1, 0,
#        0, 2, 1, 2, 2, 3, 1, 1, 3, 0, 0, 3, 3, 3, 1, 3, 1, 0, 3, 2, 1, 3,
#        3, 3, 3, 1, 0, 1, 1, 3, 1, 1, 3, 1, 0, 3, 1, 1, 2, 0, 0, 3, 2, 3,
# ...

# %%
data_test['price_range']=predicted_price

# %%
data_test
# Out:
#      battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0             1043     1          1.8         1  14       0           5
# 1              841     1          0.5         1   4       1          61
# 2             1807     1          2.8         0   1       0          27
# 3             1546     0          0.5         1  18       1          25
# 4             1434     0          1.4         0  11       1          49
# ..             ...   ...          ...       ...  ..     ...         ...
# 995           1700     1          1.9         0   0       1          54
# 996            609     0          1.8         1   0       0          13
# 997           1185     0          1.4         0   1       1           8
# 998           1533     1          0.5         1   0       0          50
# 999           1270     1          0.5         0   4       1          35
#
#      m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %% [markdown]
# #Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier(n_estimators=200)
rfc.fit(x_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=200)

# %%
rfc.score(x_test,y_test)
# Out:
# 0.896

# %% [markdown]
# #  RF ¶

# %%
data_test2=pd.read_csv("test.csv")
data_test
# Out:
#      battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0             1043     1          1.8         1  14       0           5
# 1              841     1          0.5         1   4       1          61
# 2             1807     1          2.8         0   1       0          27
# 3             1546     0          0.5         1  18       1          25
# 4             1434     0          1.4         0  11       1          49
# ..             ...   ...          ...       ...  ..     ...         ...
# 995           1700     1          1.9         0   0       1          54
# 996            609     0          1.8         1   0       0          13
# 997           1185     0          1.4         0   1       1           8
# 998           1533     1          0.5         1   0       0          50
# 999           1270     1          0.5         0   4       1          35
#
#      m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
data_test2=data_test2.drop('id',axis=1)

# %%
data_test.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0           1043     1          1.8         1  14       0           5    0.1
# 1            841     1          0.5         1   4       1          61    0.8
# 2           1807     1          2.8         0   1       0          27    0.9
# 3           1546     0          0.5         1  18       1          25    0.5
# 4           1434     0          1.4         0  11       1          49    0.5
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        193        3  ...        226      1412  3476    12     7          2
# 1        191        5  ...        746       857  3895     6     0          7
# 2        186        3  ...       1270      1366  2396    17    10         10
# 3         96        8  ...        295      1752  3893    10     0          7
# 4        108        6  ...        749       810  1773    15     8          7
#
# ...

# %%
predicted_price2=rfc.predict(data_test2)

# %%
predicted_price2
# Out:
# array([3, 3, 2, 3, 1, 3, 3, 1, 3, 0, 3, 3, 0, 0, 2, 0, 1, 1, 3, 2, 1, 3,
#        1, 1, 3, 0, 2, 0, 2, 0, 2, 0, 3, 0, 0, 1, 3, 1, 2, 1, 1, 2, 0, 0,
#        0, 1, 0, 3, 1, 2, 2, 0, 3, 0, 3, 1, 3, 1, 1, 3, 3, 2, 0, 1, 1, 1,
#        1, 2, 1, 1, 1, 2, 2, 3, 3, 0, 2, 0, 2, 3, 1, 3, 3, 0, 3, 0, 3, 1,
#        3, 0, 1, 1, 2, 0, 2, 1, 0, 2, 1, 2, 1, 0, 0, 3, 1, 2, 0, 1, 2, 3,
#        3, 3, 1, 3, 3, 3, 3, 1, 3, 0, 0, 3, 2, 1, 1, 0, 3, 2, 3, 1, 0, 1,
#        1, 1, 3, 1, 2, 0, 3, 2, 1, 3, 2, 2, 2, 3, 3, 2, 2, 3, 2, 3, 0, 0,
#        2, 2, 3, 3, 3, 3, 2, 2, 3, 3, 3, 3, 1, 0, 3, 0, 0, 0, 1, 1, 0, 1,
#        0, 0, 1, 2, 0, 0, 0, 1, 2, 2, 2, 1, 0, 0, 0, 1, 0, 3, 1, 0, 2, 2,
#        2, 3, 1, 2, 3, 3, 3, 2, 2, 1, 0, 0, 1, 3, 0, 2, 3, 3, 0, 2, 0, 3,
#        2, 3, 3, 0, 0, 1, 0, 3, 0, 1, 0, 2, 2, 1, 3, 0, 3, 0, 3, 1, 2, 0,
#        0, 2, 1, 3, 3, 3, 1, 1, 3, 0, 0, 2, 3, 3, 1, 3, 1, 1, 3, 2, 1, 2,
#        3, 3, 3, 1, 0, 1, 2, 3, 1, 1, 3, 2, 0, 3, 0, 1, 2, 0, 0, 3, 2, 3,
# ...

# %%
data_test2['price_range']=predicted_price2

# %%
data_test2
# Out:
#      battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0             1043     1          1.8         1  14       0           5
# 1              841     1          0.5         1   4       1          61
# 2             1807     1          2.8         0   1       0          27
# 3             1546     0          0.5         1  18       1          25
# 4             1434     0          1.4         0  11       1          49
# ..             ...   ...          ...       ...  ..     ...         ...
# 995           1700     1          1.9         0   0       1          54
# 996            609     0          1.8         1   0       0          13
# 997           1185     0          1.4         0   1       1           8
# 998           1533     1          0.5         1   0       0          50
# 999           1270     1          0.5         0   4       1          35
#
#      m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...
